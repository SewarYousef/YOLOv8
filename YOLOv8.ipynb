# %% [markdown]
# <a href="https://colab.research.google.com/github/SewarYousef/YOLOv8/blob/main/YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**YOLOv8 Model**

# %% [markdown]
# First thing we want to make sure that we have access to GPU
#
# ***Make sure to change your Runtime tupe to GPU before running this code!***

# %%
# !nvidia-smi
# Out:
# Fri May  3 16:41:59 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# This to make me save files from their URLs

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# #Setup
#
# Pip install `ultralytics`, dependencies, and check software and hardware

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.8/78.2 GB disk)

# %% [markdown]
# Import `display` and `Image` functions to show images

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# # YOLOv8 Tasks
#
# YOLOv8 can train, val, predict and export models for the most common tasks in vision AI: Classify, Detect, Segment, and Pose

# %% [markdown]
# ![banner-tasks.png](data:image/png;base64,...)

# %% [markdown]
# ##1. Classify
#
# YOLOv8 classification models use the -cls suffix, such as yolov8n-cls.pt and are pretrained on ImageNet

# %%
# %cd {HOME}
# !yolo task=classify mode=predict model=yolov8n-cls.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg' save=True

# conf=0.25 Sets the confidence threshold for detections to %25
# Which means only detections with confidence scores higher than 0.25 will be considered
# Out:
# /content
# ...
# 100% 5.30M/5.30M [00:00<00:00, 60.7MB/s]
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 17.7MB/s]
# ...
# 100% 755k/755k [00:00<00:00, 25.3MB/s]
# image 1/1 /content/bus.jpg: 224x224 minibus 0.54, police_van 0.24, trolleybus 0.06, golfcart 0.02, streetcar 0.02, 2.8ms
# Speed: 46.6ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/classify/predict/bus.jpg', height=600)
# Out:
# /content

# %% [markdown]
# ##2. Detect
#
# YOLOv8 detection models have no suffix and are the default YOLOv8 models, such as `yolov8n.pt` and are pretrained on COCO.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg' save=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 115MB/s]
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 209.2ms
# Speed: 16.7ms preprocess, 209.2ms inference, 3748.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/bus.jpg', height=600)
# Out:
# /content

# %% [markdown]
# ##3. Segment
#
# YOLOv8 segmentation models use the -seg suffix, such as yolov8n-seg.pt and are pretrained on COCO

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model=yolov8n-seg.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg' save=True
# Out:
# /content
# ...
# 100% 6.73M/6.73M [00:00<00:00, 118MB/s]
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 172.2ms
# Speed: 3.9ms preprocess, 172.2ms inference, 1913.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/segment/predict/bus.jpg', height=600)
# Out:
# /content

# %% [markdown]
# ##4. Pose
#
# YOLOv8 pose models use the -pose suffix, such as yolov8n-pose.pt and are pretrained on COCO Keypoints

# %%
# %cd {HOME}
# !yolo task=pose mode=predict model=yolov8n-pose.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg' save=True
# Out:
# /content
# ...
# 100% 6.51M/6.51M [00:00<00:00, 108MB/s]
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-pose summary (fused): 187 layers, 3289964 parameters, 0 gradients, 9.2 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 110.0ms
# Speed: 4.5ms preprocess, 110.0ms inference, 2103.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/pose/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/pose/predict/bus.jpg', height=600)
# Out:
# /content

# %% [markdown]
# ##5. Oriented Bounding Boxes (OBB) ***Extra model***
#
# YOLOv8 OBB models use the -obb suffix, such as yolov8n-obb.pt and are pretrained on the DOTA dataset

# %%
# %cd {HOME}
# !yolo task=obb mode=predict model=yolov8n-obb.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg' save=True
# Out:
# /content
# ...
# 100% 6.24M/6.24M [00:00<00:00, 115MB/s]
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-obb summary (fused): 187 layers, 3080144 parameters, 0 gradients, 8.3 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 1024x768 119.0ms
# Speed: 8.3ms preprocess, 119.0ms inference, 1602.7ms postprocess per image at shape (1, 3, 1024, 768)
# Results saved to runs/obb/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/obb/predict/bus.jpg', height=600)
# Out:
# /content
